# %% [markdown]
# # What Model Can Answer This Question?
#
# Available model types:
#
# Regression:
#
# Linear Regression
# KNN Regression
# Random Forest Regression
# Ridge Regression
# LASSO Regression
# SVM Regression
#
# Classification:
#
# Naive Bayes
# KNN Classification
# Decision Trees
# Random Forest Classification
# Logistic Regression
# Ridge Logistic Regression
# LASSO Logistic Regression
# SVM Classifier
#
# Other Techniques:
#
# PCA
# Boosting

# %% [markdown]
# Answer for all questions: try one form of regression/classification and see if it works, then compare it to another model that's appropriate for the same kind of outcome variable.
#
#
#
# ## 1. Predict the running times of prospective Olympic sprinters using data from the last 20 Olympics.
#
#
# Linear Regression/KNN
#
#
# ## 2. You have more features (columns) than rows in your dataset.
#
#
# Random Forest, PCA, (LASSO Regression)
#
#
# ## 3. Identify the most important characteristic predicting likelihood of being jailed before age 20.
#
#
# Random Forest Classification/Gradient Boosting Classification
#
#
# ## 4. Implement a filter to “highlight” emails that might be important to the recipient.
#
#
# Naive Bayes (Try some kind of boosting)
#
#
# ## 5. You have 1000+ features.
#
#
# LASSO Regression/PCA
#
#
# ## 6. Predict whether someone who adds items to their cart on a website will purchase the items.
#
#
# KNN Classifier
#
#
# ## 7. Your dataset dimensions are 982400 x 500
#
#
# Gradient Boosting
#
#
# ## 8. Identify faces in an image.
#
#
# SVC - 3d-2d transformations w/PCA
# PCA w/Random Forest
# Gradient Boosting Classification
#
#
# ## 9. Predict which of three flavors of ice cream will be most popular with boys vs girls.
#
#
# Decision Tree
